# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from geopy.geocoders import Nominatim
import time
from pprint import pprint

# %%
city_state = input("What city, state are you in?")
# Out:
# What city, state are you in?Poughkeepsie, NY

# %%
# instantiate a new Nominatim client
app = Nominatim(user_agent="tutorial")

# %%
location = app.geocode(city_state).raw
pprint(location)
# Out:
# {'boundingbox': ['41.670257', '41.716976', '-73.946377', '-73.890811'],
#  'class': 'boundary',
#  'display_name': 'City of Poughkeepsie, Dutchess County, New York, 12601, '
#                  'United States',
#  'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#  'importance': 0.6183317647068666,
#  'lat': '41.7065539',
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. '
#             'https://osm.org/copyright',
#  'lon': '-73.9283672',
#  'osm_id': 174952,
#  'osm_type': 'relation',
#  'place_id': 298030765,
#  'type': 'administrative'}

# %%
lat = location['lat']

# %%
long = location['lon']

# %%
lat_long = [lat,long]
print(lat_long)
# Out:
# ['41.7065539', '-73.9283672']

# %%
# Connect with Yelp API to find restaurant in area.
import requests
# GET https://api.yelp.com/v3/businesses/search

# Import API key
from config import Yelp_API_key

# %%
pip install yelpapi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from yelpapi import YelpAPI
with YelpAPI(Yelp_API_key) as yelp_api:
#     search_results = yelp_api.search_query(args)
    response = yelp_api.search_query(latitude = [lat], longitude = [long])

# %%
# from yelpapi import YelpAPI
# import argparse
# argparser = argparse.ArgumentParser
# argparser.add_argument('api_key', type=str, help='Yelp Fusion API Key')
# args = argparser.parse_args()
# with YelpAPI(args.api_key) as yelp_api:
  
#     response = response = yelp_api.search_query(latitude = [lat], longitude = [long])
pprint(response)
# Out:
# {'businesses': [{'alias': 'rossi-rosticceria-deli-poughkeepsie',
#                  'categories': [{'alias': 'delis', 'title': 'Delis'},
#                                 {'alias': 'italian', 'title': 'Italian'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#                  'coordinates': {'latitude': 41.7038841247559,
#                                  'longitude': -73.9355773925781},
#                  'display_phone': '(845) 471-0654',
#                  'distance': 668.132238681627,
#                  'id': 'FdReXpZQSN_OYtrOsYEdpA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dA7VHOjFcHawRnv9H4QK1g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '45 S Clover St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Poughkeepsie',
#                               'country': 'US',
# ...

# %%
#Starting URL for Yelp API call.
# url = "https://api.yelp.com/v3/business_search"
# response = yelp_api.search_query(latitude = [lat], longitude = [long])
# pprint(response)
print(response['businesses'])
# Out:
# [{'id': 'FdReXpZQSN_OYtrOsYEdpA', 'alias': 'rossi-rosticceria-deli-poughkeepsie', 'name': 'Rossi Rosticceria Deli', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dA7VHOjFcHawRnv9H4QK1g/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/rossi-rosticceria-deli-poughkeepsie?adjust_creative=v9nnSEHQjm4DOrvM3_PeIg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=v9nnSEHQjm4DOrvM3_PeIg', 'review_count': 564, 'categories': [{'alias': 'delis', 'title': 'Delis'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}], 'rating': 4.5, 'coordinates': {'latitude': 41.7038841247559, 'longitude': -73.9355773925781}, 'transactions': [], 'price': '$$', 'location': {'address1': '45 S Clover St', 'address2': '', 'address3': '', 'city': 'Poughkeepsie', 'zip_code': '12601', 'country': 'US', 'state': 'NY', 'display_address': ['45 S Clover St', 'Poughkeepsie, NY 12601']}, 'phone': '+18454710654', 'display_phone': '(845) 471-0654', 'd
# ...

# %%
# import argparse
# argparser = argparse.ArgumentParser
# args = argparser.parse_args('self')
businesses = response['businesses']

# %%
businesses = pd.DataFrame(businesses)
businesses.head()
# Out:
#                        id                                              alias  \
# 0  FdReXpZQSN_OYtrOsYEdpA                rossi-rosticceria-deli-poughkeepsie
# 1  8DVS1sg8kP_53CH5rgw2XQ            mill-house-brewing-company-poughkeepsie
# 2  n7BJXy15sYe4Eg2lEJ23Ng                the-poughkeepsie-grind-poughkeepsie
# 3  oSNZnnB9jBqnkvEdWPHOkg  walkway-over-the-hudson-state-historic-park-po...
# 4  vgOByH17vx1NLd9tNrN2XA                     el-azteca-mexican-poughkeepsie
#
#                                           name  \
# 0                       Rossi Rosticceria Deli
# 1                   Mill House Brewing Company
# 2                       The Poughkeepsie Grind
# 3  Walkway Over the Hudson State Historic Park
# 4                            El Azteca Mexican
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/dA7VHO...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/t7LvjL...      False
# ...

# %%
names = []
for business in businesses:
    names = businesses['name'].append(names)


print(names)
# Out:
# 0                          Rossi Rosticceria Deli
# 1                      Mill House Brewing Company
# 2                          The Poughkeepsie Grind
# 3     Walkway Over the Hudson State Historic Park
# 4                               El Azteca Mexican
#                          ...
# 15                                Farmers & Chefs
# 16                                   La Deliziosa
# 17                                   Falafel Town
# 18                   Sylvia's Jamaican Restaurant
# 19                                    La Cabanita
# Name: name, Length: 320, dtype: object

# %%
#Randomly generate local restaurant to eat
import random
import numpy
random_restaurant = numpy.random.choice(names)
print("Since you don't know where you want to eat tonight -- You are eating at:")
print(random_restaurant)
# Out:
# Since you don't know where you want to eat tonight -- You are eating at:
# Tavern23
